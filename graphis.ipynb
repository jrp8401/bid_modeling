# %%
Big Bid                         0.220125
Department: Estimating          0.128309
Negotiated Bid                  0.114195
Budget Bid                      0.099324
Design/Build                    0.092416
Competitive Bid                 0.092363
75% Bid                         0.082127
Orange County                   0.070982
50% Bid                         0.045616
Department: Project Managers    0.031933
Design/Assist                   0.022610
# Out:
#   File "<ipython-input-1-c22a97581f6f>", line 1
#     Big Bid                         0.220125
#           ^
# SyntaxError: invalid syntax

# %%
names = ['Bid$ >$116,000','Department: Estimating','Bid Type: Negotiated', 'Bid Type: Budget','Design: Design/Build', 'Bid Type: Competitive','Bid$ < $116,000','Orange County','Bid <$18,000','Department: Project Managers','Design: Design/Assist']
imports = [.22,.128,.114,.099,.0924,.0923,.082,.07,.045,.032,.023]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
f, ax = plt.subplots(figsize=(12,8))
important_features = pd.Series(data=imports,index=names)
important_features.sort_values(ascending=False,inplace=True)
important_features.nlargest(12).plot(kind = 'barh')
